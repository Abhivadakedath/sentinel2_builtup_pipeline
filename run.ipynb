# %% [markdown]
# # Download sentinel 2 images

# %%
from scripts.download_s2_pc_by_tile import run as run_download

run_download(
    outdir="data/sentinel",
    aoi_path="data/aoi/CMDA.shp",
    year=2025,
)
# Out:
# /Users/athithiyan/anaconda3/envs/lila/lib/python3.10/site-packages/pystac_client/item_search.py:925: FutureWarning: get_items() is deprecated, use items() instead
#   warnings.warn(
# 2026-01-05 11:18:54,154 INFO: Found 175 Sentinel-2 items
# 2026-01-05 11:18:54,318 INFO: Monthly download completed successfully.

# %% [markdown]
# # Calculating mean indices [NDVI, NDBI,BSI,NDWI]

# %%
from scripts.mean_indices import run as run_indices

run_indices(
    tiles=["T44PLV","T44PMV"],
    years=[2025],
    indices=["NDVI","NDBI","BSI","MNDWI","SAVI","IBI"],
    aggregate_mean=True,
    aggregate_median=True,
    overwrite_monthly=False,
)

# indices=("NDVI","NDBI","BSI","MNDWI","SAVI","IBI")
# Out:
# 2026-01-05 11:19:44,384 INFO: [2023 February] indices exist → skipped
# 2026-01-05 11:19:44,385 INFO: [2023 March] indices exist → skipped
# 2026-01-05 11:19:44,386 INFO: [2023 April] indices exist → skipped
# 2026-01-05 11:19:44,389 INFO: [2023 May] indices exist → skipped
# 2026-01-05 11:19:44,390 INFO: [2023 July] indices exist → skipped
# 2026-01-05 11:19:44,390 INFO: [2023 August] indices exist → skipped
# 2026-01-05 11:19:44,391 INFO: [2023 September] indices exist → skipped
# [########################################] | 100% Completed | 59.26 s
# [#######                                 ] | 17% Completed | 11.81 ss
# /Users/athithiyan/anaconda3/envs/lila/lib/python3.10/site-packages/dask/utils.py:78: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# [########################################] | 100% Completed | 61.18 s
# 2026-01-05 11:21:54,452 INFO: [T44PLV 2023] aggregated NDVI
# [########################################] | 100% Completed | 76.72 s
# [######                                  ] | 16% Completed | 22.83 ss
# /Users/athithiyan/anaconda3/envs/lila/lib/python3.10/site-packages/dask/utils.py:78: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# [########################################] | 100% Completed | 107.36 s
# 2026-01-05 11:25:09,055 INFO: [T44PLV 2023] aggregated NDBI
# [########################################] | 100% Completed | 114.56 s
# [#######                                 ] | 17% Completed | 13.14 ss
# /Users/athithiyan/anaconda3/envs/lila/lib/python3.10/site-packages/dask/utils.py:78: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# [########################################] | 100% Completed | 62.16 s
# 2026-01-05 11:28:22,949 INFO: [T44PLV 2023] aggregated BSI
# [########################################] | 100% Completed | 59.06 s
# [######                                  ] | 17% Completed | 11.22 ss
# /Users/athithiyan/anaconda3/envs/lila/lib/python3.10/site-packages/dask/utils.py:78: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# [########################################] | 100% Completed | 61.05 s
# 2026-01-05 11:30:33,299 INFO: [T44PLV 2023] aggregated MNDWI
# [########################################] | 100% Completed | 59.73 s
# [########################################] | 100% Completed | 62.05 s
# 2026-01-05 11:32:45,375 INFO: [T44PLV 2023] aggregated SAVI
# [########################################] | 100% Completed | 62.49 s
# [######                                  ] | 17% Completed | 11.82 ss
# /Users/athithiyan/anaconda3/envs/lila/lib/python3.10/site-packages/dask/utils.py:78: RuntimeWarning: All-NaN slice encountered
#   return func(*args, **kwargs)
# [########################################] | 100% Completed | 66.95 s
# 2026-01-05 11:35:05,555 INFO: [T44PLV 2023] aggregated IBI
# /Volumes/backup_a/project/sentinel2_builtup_pipeline/scripts/mean_indices.py:57: RuntimeWarning: divide by zero encountered in divide
#   return (ndbi - (savi + mndwi) / 2) / (ndbi + (savi + mndwi) / 2)
# 2026-01-05 11:36:23,157 INFO: [2023 January] monthly indices processed
# /Volumes/backup_a/project/sentinel2_builtup_pipeline/scripts/mean_indices.py:57: RuntimeWarning: divide by zero encountered in divide
#   return (ndbi - (savi + mndwi) / 2) / (ndbi + (savi + mndwi) / 2)
# 2026-01-05 11:37:44,994 INFO: [2023 February] monthly indices processed
# /Volumes/backup_a/project/sentinel2_builtup_pipeline/scripts/mean_indices.py:57: RuntimeWarning: divide by zero encountered in divide
#   return (ndbi - (savi + mndwi) / 2) / (ndbi + (savi + mndwi) / 2)
# 2026-01-05 11:40:33,890 INFO: [2023 March] monthly indices processed
# /Volumes/backup_a/project/sentinel2_builtup_pipeline/scripts/mean_indices.py:57: RuntimeWarning: divide by zero encountered in divide
#   return (ndbi - (savi + mndwi) / 2) / (ndbi + (savi + mndwi) / 2)
# /Volumes/backup_a/project/sentinel2_builtup_pipeline/scripts/mean_indices.py:57: RuntimeWarning: invalid value encountered in divide
#   return (ndbi - (savi + mndwi) / 2) / (ndbi + (savi + mndwi) / 2)
# 2026-01-05 11:42:02,107 INFO: [2023 April] monthly indices processed
# 2026-01-05 11:43:23,208 INFO: [2023 May] monthly indices processed
# /Volumes/backup_a/project/sentinel2_builtup_pipeline/scripts/mean_indices.py:57: RuntimeWarning: divide by zero encountered in divide
#   return (ndbi - (savi + mndwi) / 2) / (ndbi + (savi + mndwi) / 2)
# 2026-01-05 11:44:56,612 INFO: [2023 June] monthly indices processed
# /Volumes/backup_a/project/sentinel2_builtup_pipeline/scripts/mean_indices.py:57: RuntimeWarning: divide by zero encountered in divide
#   return (ndbi - (savi + mndwi) / 2) / (ndbi + (savi + mndwi) / 2)
# 2026-01-05 11:46:16,792 INFO: [2023 September] monthly indices processed
# /Volumes/backup_a/project/sentinel2_builtup_pipeline/scripts/mean_indices.py:57: RuntimeWarning: divide by zero encountered in divide
#   return (ndbi - (savi + mndwi) / 2) / (ndbi + (savi + mndwi) / 2)
# 2026-01-05 11:47:34,797 INFO: [2023 November] monthly indices processed
# /Volumes/backup_a/project/sentinel2_builtup_pipeline/scripts/mean_indices.py:57: RuntimeWarning: divide by zero encountered in divide
#   return (ndbi - (savi + mndwi) / 2) / (ndbi + (savi + mndwi) / 2)
# 2026-01-05 11:48:50,580 INFO: [2023 December] monthly indices processed
# [########################################] | 100% Completed | 94.76 s
# [########################################] | 100% Completed | 95.65 s
# 2026-01-05 11:52:15,422 INFO: [T44PMV 2023] aggregated NDVI
# [########################################] | 100% Completed | 90.28 s
# [########################################] | 100% Completed | 97.32 s
# 2026-01-05 11:55:36,677 INFO: [T44PMV 2023] aggregated NDBI
# [########################################] | 100% Completed | 87.84 s
# [########################################] | 100% Completed | 84.17 s
# 2026-01-05 11:58:41,676 INFO: [T44PMV 2023] aggregated BSI
# [########################################] | 100% Completed | 91.27 s
# [########################################] | 100% Completed | 87.27 s
# 2026-01-05 12:01:51,510 INFO: [T44PMV 2023] aggregated MNDWI
# [########################################] | 100% Completed | 87.44 s
# [########################################] | 100% Completed | 87.60 s
# 2026-01-05 12:04:58,602 INFO: [T44PMV 2023] aggregated SAVI
# [########################################] | 100% Completed | 90.91 s
# [########################################] | 100% Completed | 91.15 s
# 2026-01-05 12:08:12,431 INFO: [T44PMV 2023] aggregated IBI

# %% [markdown]
# # Model and predictions

# %%
from scripts.train_and_predict_builtup import run as run_builtup

feature_files = [
    "{base}_MEAN_NDVI.tif",
#     "{base}_MEDIAN_NDVI.tif",
    "{base}_MEAN_NDBI.tif",
#     "{base}_MEDIAN_NDBI.tif",
    "{base}_MEAN_MNDWI.tif",
#     "{base}_MEDIAN_MNDWI.tif",
    "{base}_MEAN_SAVI.tif",
#     "{base}_MEDIAN_SAVI.tif",
    "{base}_MEAN_IBI.tif",
#     "{base}_MEDIAN_IBI.tif",
]

index_thresholds = {
    "NDVI":  (-0.1, 0.5),
    "MNDWI": (-0.6, -0.05),
    "NDBI":  (0.05, 1.0),
    "IBI":   (0.0, 1.0),
}

clf = run_builtup(
    root="data/sentinel",
    year="2025",
    train_vector="data/training/CMDA_overall_final.shp",
    class_col="class",
    tiles=["T44PLV", "T44PMV"],
    feature_files=feature_files,
    index_thresholds=index_thresholds,
    max_samples_per_poly=100,
    n_trees=100,
    prob_threshold=0.7,
    out_model="output/model/builtup_rf_custom_200.joblib",
)
# Out:
# 2026-01-05 13:53:32,174 INFO: Training samples: (643, 5) | Class balance: [428 215]
# 2026-01-05 13:53:32,372 INFO:
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87        86
#            1       0.81      0.58      0.68        43
#
#     accuracy                           0.81       129
#    macro avg       0.81      0.76      0.77       129
# weighted avg       0.81      0.81      0.80       129
#
# 2026-01-05 13:53:32,465 INFO: Model saved → /Volumes/backup_a/project/sentinel2_builtup_pipeline/output/model/builtup_rf_custom_200.joblib
# 2026-01-05 13:53:32,466 INFO: Predicting T44PLV (2025)
# 2026-01-05 13:56:40,716 INFO: [T44PLV] Prediction completed
# 2026-01-05 13:56:40,813 INFO: Predicting T44PMV (2025)
# 2026-01-05 14:00:38,449 INFO: [T44PMV] Prediction completed
